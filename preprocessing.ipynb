# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import os

# %%
# directory where all the data is present
base_dir = "D:\\something-something-project\\data\\"

# %%
print (base_dir)
# Out:
# D:\something-something-project\data\

# %%
# loading only training and validation json files
train_vids_id = pd.read_json(base_dir + 'something-something-v2-train.json')
validation_vids_id = pd.read_json(base_dir + 'something-something-v2-validation.json')

# %%
train_vids_id.head(50)
# Out:
#         id                                              label  \
# 0    78687        holding potato next to vicks vaporub bottle
# 1    42326                     spreading margarine onto bread
# 2   100904                           putting pen on a surface
# 3    80715  lifting up one end of bottle, then letting it ...
# 4    34899                                       holding bulb
# 5   184568            pushing strap camera from right to left
# 6   112783                    spilling mouthwash onto roll on
# 7   108895  pushing spiderman invitaion so that it slightl...
# 8   169270  moving headset across a surface until it falls...
# 9    66533                                folding paper towel
# 10   67698                            taking a slice of onion
# 11   60195                 pretending to turn hat upside down
# 12  187992         pretending to take bottle from window side
# 13  102808                            moving color pencils up
# 14  218043  twisting (wringing) shirt wet until water come...
# 15   82056                holding a pencil next to tissue box
# 16   10158                                   twisting a cloth
# 17  113667                    taking tissue out of tissue box
# 18  134982             dropping headset in front of tools bag
# 19   37055  throwing sunscreen in the air and letting it fall
# 20  199780  lifting up one end of card without letting it ...
# 21  122775                 moving notebook towards the camera
# 22  151369                            moving coconut wafer up
# 23  170911                      showing that tumbler is empty
# 24   25020                      dropping biscuit behind razor
# 25  116814                      throwing a stone against tree
# 26  122986                            holding pencil over box
# 27  216433  moving a pouch and a mobile phone closer to ea...
# 28   47323                    pushing iron from right to left
# 29   15409                           pushing coin so it spins
# 30  123183               covering a water bottle with a cloth
# 31  208007               putting match into empty pill bottle
# 32   63908                  showing that pen is inside bucket
# 33  156381                                   throwing headset
# 34  116989                   pulling knife from right to left
# 35  114072                    tipping disposable lighter over
# 36  203597  moving tomato across a surface until it falls ...
# 37   14991                          covering stone with paper
# 38  101299              pulling chopsticks from right to left
# 39  186594  poking a stack of tiles without the stack coll...
# 40  111183           letting marble roll along a flat surface
# 41  105168  showing 'enak' vanilla canned milk behind 'tig...
# 42  190776                     dropping compass tool onto box
# 43  181638   throwing a calculator in the air and catching it
# 44  140721                     throwing a ball against a sofa
# 45  145959                                    squeezing paper
# 46  201957                         pushing pencil off of book
# 47   20060           throwing card in the air and catching it
# 48  203403       moving polish and a box closer to each other
# 49  133878        pushing newspaper so that it slightly moves
#
#                                              template  \
# 0             Holding [something] next to [something]
# 1              Spreading [something] onto [something]
# 2                    Putting [something] on a surface
# 3   Lifting up one end of [something], then lettin...
# 4                                 Holding [something]
# 5              Pushing [something] from right to left
# 6               Spilling [something] onto [something]
# 7       Pushing [something] so that it slightly moves
# 8   Moving [something] across a surface until it f...
# 9                                 Folding [something]
# 10   Taking [one of many similar things on the table]
# 11         Pretending to turn [something] upside down
# 12    Pretending to take [something] from [somewhere]
# 13                              Moving [something] up
# 14  Twisting (wringing) [something] wet until wate...
# 15            Holding [something] next to [something]
# 16                               Twisting [something]
# 17              Taking [something] out of [something]
# 18       Dropping [something] in front of [something]
# 19  Throwing [something] in the air and letting it...
# 20  Lifting up one end of [something] without lett...
# 21              Moving [something] towards the camera
# 22                              Moving [something] up
# 23                  Showing that [something] is empty
# 24            Dropping [something] behind [something]
# 25           Throwing [something] against [something]
# 26               Holding [something] over [something]
# 27  Moving [something] and [something] closer to e...
# 28             Pushing [something] from right to left
# 29                    Pushing [something] so it spins
# 30              Covering [something] with [something]
# 31               Putting [something] into [something]
# 32     Showing that [something] is inside [something]
# 33                               Throwing [something]
# 34             Pulling [something] from right to left
# 35                           Tipping [something] over
# 36  Moving [something] across a surface until it f...
# 37              Covering [something] with [something]
# 38             Pulling [something] from right to left
# 39  Poking a stack of [something] without the stac...
# 40      Letting [something] roll along a flat surface
# 41             Showing [something] behind [something]
# 42              Dropping [something] onto [something]
# 43    Throwing [something] in the air and catching it
# 44           Throwing [something] against [something]
# 45                              Squeezing [something]
# 46             Pushing [something] off of [something]
# 47    Throwing [something] in the air and catching it
# 48  Moving [something] and [something] closer to e...
# 49      Pushing [something] so that it slightly moves
#
#                                          placeholders
# 0                      [potato, vicks vaporub bottle]
# 1                                  [margarine, bread]
# 2                                               [pen]
# 3                                            [bottle]
# 4                                              [bulb]
# 5                                      [strap camera]
# 6                                [mouthwash, roll on]
# 7                               [spiderman invitaion]
# 8                                           [headset]
# 9                                       [paper towel]
# 10                                 [a slice of onion]
# 11                                              [hat]
# 12                              [bottle, window side]
# 13                                    [color pencils]
# 14                                            [shirt]
# 15                             [a pencil, tissue box]
# 16                                          [a cloth]
# 17                               [tissue, tissue box]
# 18                               [headset, tools bag]
# 19                                        [sunscreen]
# 20                                             [card]
# 21                                         [notebook]
# 22                                    [coconut wafer]
# 23                                          [tumbler]
# 24                                   [biscuit, razor]
# 25                                    [a stone, tree]
# 26                                      [pencil, box]
# 27                          [a pouch, a mobile phone]
# 28                                             [iron]
# 29                                             [coin]
# 30                          [a water bottle, a cloth]
# 31                         [match, empty pill bottle]
# 32                                      [pen, bucket]
# 33                                          [headset]
# 34                                            [knife]
# 35                               [disposable lighter]
# 36                                           [tomato]
# 37                                     [stone, paper]
# 38                                       [chopsticks]
# 39                                            [tiles]
# 40                                           [marble]
# 41  ['enak' vanilla canned milk, 'tiga sapi' choco...
# 42                                [compass tool, box]
# 43                                     [a calculator]
# 44                                   [a ball, a sofa]
# 45                                            [paper]
# 46                                     [pencil, book]
# 47                                             [card]
# 48                                    [polish, a box]
# 49                                        [newspaper]

# %%
train_vids_id.shape
# Out:
# (168913, 4)

# %%
validation_vids_id.head()
# Out:
#        id                                              label  \
# 0   74225          spinning cube that quickly stops spinning
# 1  116154                  showing clay box on top of wallet
# 2  198186                        wiping words off of a paper
# 3  137878    pushing scissors so that it falls off the table
# 4  151151  turning the camera left while filming wall mou...
#
#                                             template        placeholders
# 0   Spinning [something] that quickly stops spinning              [cube]
# 1          Showing [something] on top of [something]  [clay box, wallet]
# 2              Wiping [something] off of [something]    [words, a paper]
# 3  Pushing [something] so that it falls off the t...          [scissors]
# 4  Turning the camera left while filming [something]  [wall mounted fan]

# %%
validation_vids_id.shape
# Out:
# (24777, 4)

# %%
# grouping the data based on following classes, grouping together all the data which belongs to one action
# we will be using below 9 classes:
classes = {'Dropping [something]' : [], 
           'Holding [something]' : [],
           'Moving [something]' : [], 
           'Picking [something]' : [],
           'Poking [something]' : [],
           'Pouring [something]' : [],
           'Putting [something]' : [],
           'Showing [something]' : [], 
           'Tearing [something]' : []}

actual_class = {'Dropping [something]' : 'Dropping_something', 
           'Holding [something]' : 'Holding_something',
           'Moving [something]' : 'Moving_something', 
           'Picking [something]' : 'Picking_something',
           'Poking [something]' : 'Poking_something',
           'Pouring [something]' : 'Pouring_something',
           'Putting [something]' : 'Putting_something',
           'Showing [something]' : 'Showing_something', 
           'Tearing [something]' : 'Tearing_something'}

# %%
# utility function to return the class name from the template name
def get_class_name(template_name):
    for key in classes:
        if key in template_name:
            return key
    return None

# %%
# grouping the training data
# iterating the pd dataframe
for index, row in train_vids_id.iterrows():
    row_class = get_class_name(row['template'])
    if (row_class != None):
        # print ('Template: ', row['template'], '\tclass: ', row_class)
        classes[row_class].append((row['id'], row['placeholders'][0]))

# %%
classes['Dropping [something]'][100][1]
# Out:
# 'shoe cleaning brush'

# %%
# printing the len of each class
for key in classes:
    print ('Class: ', key, '\t\tLength: ', len(classes[key]))

    holding something : ~14k
# Out:
# Class:  Dropping [something] 		Length:  4680
# Class:  Holding [something] 		Length:  6894
# Class:  Moving [something] 		Length:  14877
# Class:  Picking [something] 		Length:  980
# Class:  Poking [something] 		Length:  4194
# Class:  Pouring [something] 		Length:  1700
# Class:  Putting [something] 		Length:  16731
# Class:  Showing [something] 		Length:  4141
# Class:  Tearing [something] 		Length:  3021

# %%
# we got our classes and it's count
# let's start getting images as 0.5 fps and store them in their respective folders
import cv2

# %%
count = 1

# function to extract frames and save it in respective class folder
def getFrame(sec, vidcap, output_dir, class_name, obj, count):
    vidcap.set(cv2.CAP_PROP_POS_MSEC, sec*1000)
    hasFrames, image = vidcap.read()
    if hasFrames:
        if not os.path.exists(output_dir + actual_class[class_name]): 
            os.makedirs(output_dir + actual_class[class_name])
        
        os.chdir(output_dir + actual_class[class_name])
        cv2.imwrite(actual_class[class_name].split('_')[0] + '_' + obj + '_' + str(count) + ".jpg", image)     # save frame as JPG file
    return hasFrames

# %%
# since we will be using different classes in the dict to generate images,
# let's hope for now there are no overlapping of vids in different keys.
# To make things faster, lets implement multi-processing in python so that
# our code executes faster and utilizes more cpu.

# %%
# run this cell if you want to simply generate images without multi-processing

# directory where all the videos are saved
video_dir = 'D:\\something-something-project\\data\\videos\\20bn-something-something-v2\\'
# directory where images will be saved
output_dir = 'D:\\something-something-project\\test-images\\'

for key in classes:
    global count
    count = 1
    print ("Current class: ", key)
    break_flag = False
    for vid in classes[key]:
        vidcap = cv2.VideoCapture(video_dir + str(vid[0]) + '.webm')
        sec = 0
        fps = 1
        success = getFrame(sec, vidcap, output_dir, key, vid[1], count)
        while success:
            count = count + 1
            # limiting the number of images (frames) per class to 5000
#             if (count == 5000):
#                 break_flag = True
#                 break
            sec = sec + fps
            sec = round(sec, 2)
            success = getFrame(sec, vidcap, output_dir, key, vid[1], count)
#         if break_flag:
#             break
        break
    break
# Out:
# Current class:  Dropping [something]

# %%
# doing the same thing for validation set now

# grouping the data based on following classes, grouping together all the data which belongs to one action
# we will be using below 9 classes:
validation_classes = {'Dropping [something]' : [], 
           'Holding [something]' : [],
           'Moving [something]' : [], 
           'Picking [something]' : [],
           'Poking [something]' : [],
           'Pouring [something]' : [],
           'Putting [something]' : [],
           'Showing [something]' : [], 
           'Tearing [something]' : []}


# utility function to return the class name from the template name
def get_validation_class_name(template_name):
    for key in validation_classes:
        if key in template_name:
            return key
    return None


# grouping the validation data
# iterating the pd dataframe
for index, row in validation_vids_id.iterrows():
    row_class = get_validation_class_name(row['template'])
    if (row_class != None):
        # print ('Template: ', row['template'], '\tclass: ', row_class)
        validation_classes[row_class].append(row['id'])
        
# printing the len of each class
for key in validation_classes:
    print ('Class: ', key, '\t\tLength: ', len(validation_classes[key]))
# Out:
# Class:  Dropping [something] 		Length:  827
# Class:  Holding [something] 		Length:  1053
# Class:  Moving [something] 		Length:  1911
# Class:  Picking [something] 		Length:  199
# Class:  Poking [something] 		Length:  419
# Class:  Pouring [something] 		Length:  458
# Class:  Putting [something] 		Length:  1894
# Class:  Showing [something] 		Length:  697
# Class:  Tearing [something] 		Length:  898

# %%
# write the validation classes data into the disk
count = 1

# function to extract frames and save it in respective class folder
def getValidationFrame(sec, vidcap, output_dir, class_name, count):
    vidcap.set(cv2.CAP_PROP_POS_MSEC, sec*1000)
    hasFrames, image = vidcap.read()
    if hasFrames:
        if not os.path.exists(output_dir + actual_class[class_name]): 
            os.makedirs(output_dir + actual_class[class_name])
        
        os.chdir(output_dir + actual_class[class_name])
        cv2.imwrite(actual_class[class_name] + '_image_' + str(count) + ".jpg", image)     # save frame as JPG file
    return hasFrames

# %%
# directory where all the videos are saved
video_dir = 'D:\\something-something-project\\data\\videos\\20bn-something-something-v2\\'
# directory where images will be saved
output_dir = 'D:\\something-something-project\\validation-images\\'

for key in validation_classes:
    global count
    count = 1
    print ("Current class: ", key)
    for vid in validation_classes[key]:
        vidcap = cv2.VideoCapture(video_dir + str(vid) + '.webm')
        sec = 0
        fps = 0.5
        success = getValidationFrame(sec, vidcap, output_dir, key, count)
        while success:
            count = count + 1
            sec = sec + fps
            sec = round(sec, 2)
            success = getValidationFrame(sec, vidcap, output_dir, key, count)
# Out:
# Current class:  Dropping [something]
# Current class:  Holding [something]
# Current class:  Moving [something]
# Current class:  Picking [something]
# Current class:  Poking [something]
# Current class:  Pouring [something]
# Current class:  Putting [something]
# Current class:  Showing [something]
# Current class:  Tearing [something]
